# %%
import tiktoken

encoding = tiktoken.encoding_for_model("gpt-2")
tokens = encoding.encode("Breast cancer Drug is Doxirubicin")
print(tokens)
# Out:
# [12679, 459, 4890, 11095, 318, 360, 1140, 343, 549, 291, 259]

# %%
for token_id in tokens:
    token_text = encoding.decode([token_id])
    print(f"{token_id} = {token_text}")
# Out:
# 12679 = Bre
# 459 = ast
# 4890 =  cancer
# 11095 =  Drug
# 318 =  is
# 360 =  D
# 1140 = ox
# 343 = ir
# 549 = ub
# 291 = ic
# 259 = in

# %%
from openai import OpenAI

openai = OpenAI()
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "Hi! I'm Ed!"}
    ]
response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages,
    temperature=0.5,
    max_tokens=100
)
response.choices[0].message.content
